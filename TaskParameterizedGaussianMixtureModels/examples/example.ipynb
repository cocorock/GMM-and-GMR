# %% [markdown]
# # Examples for Task Parameterized Gaussian Mixture Models

# %% [markdown]
# Load dataset. You can find more details about the dataset at: https://theairlab.org/trajair/

# %%
import sys

sys.path.append("/".join(sys.path[0].split("/")[:-1]))

# %%
from tpgmm.utils.file_system import load_txt
from tpgmm.utils.casting import ssv_to_ndarray

from tpgmm.utils.plot.plot import plot_trajectories

import numpy as np

from glob import glob
from numpy import ndarray
# Out:
# C:\Users\quepe\Documents\GitHub\GMM-and-GMR\TaskParameterizedGaussianMixtureModels\tpgmm\gmr\gmr.py:19: SyntaxWarning: invalid escape sequence '\m'
#   \mathcal{P}(\phi_t^\mathcal{O}|\phi_t^\mathcal{I}) \sim \sum_{i=1}^K h_i(\phi_t^\mathcal{I}) \mathcal{N}\left(\hat{\mu}_t^\mathcal{O}(\phi_t^\mathcal{I}), \hat{\Sigma}_t^\mathcal{O}\right)
# C:\Users\quepe\Documents\GitHub\GMM-and-GMR\TaskParameterizedGaussianMixtureModels\tpgmm\gmr\gmr.py:144: SyntaxWarning: invalid escape sequence '\m'
#   \mathcal{P}(\phi_t^\mathcal{O}|\phi_t^\mathcal{I}) \sim \sum_{i=1}^K h_i(\phi_t^\mathcal{I}) \mathcal{N}\left(\hat{\mu}_t^\mathcal{O}(\phi_t^\mathcal{I}), \hat{\Sigma}_t^\mathcal{O}\right)
# C:\Users\quepe\Documents\GitHub\GMM-and-GMR\TaskParameterizedGaussianMixtureModels\tpgmm\gmr\gmr.py:212: SyntaxWarning: invalid escape sequence '\p'
#   h_i(\phi_t^\mathcal{I}) = \frac{\pi_i \mathcal{N}(\phi_t^\mathcal{I} \mid \mu_i^\mathcal{I}, \Sigma_i^\mathcal{I})}{\sum_k^K \pi_k \mathcal{N}\mathcal(\phi_t^\mathcal{I} \mid \mu_k^\mathcal{I}, \Sigma_k^\mathcal{I})}
# C:\Users\quepe\Documents\GitHub\GMM-and-GMR\TaskParameterizedGaussianMixtureModels\tpgmm\gmr\gmr.py:245: SyntaxWarning: invalid escape sequence '\h'
#   \hat{\mu}_i^\mathcal{O}(\phi_t^\mathcal{I}) = \mu_i^\mathcal{O} + \Sigma_i^\mathcal{OI}\Sigma_i^{\mathcal{I}, -1}(\phi_t^\mathcal{I} - \mu_i^\mathcal{I})
# C:\Users\quepe\Documents\GitHub\GMM-and-GMR\TaskParameterizedGaussianMixtureModels\tpgmm\gmr\gmr.py:277: SyntaxWarning: invalid escape sequence '\h'
#   \hat{\Sigma}_t^\mathcal{O} = \Sigma_i^\mathcal{O} - \Sigma_i^\mathcal{OI}\Sigma_i^{\mathcal{I}, -1}\Sigma_i^\mathcal{OI}
# C:\Users\quepe\Documents\GitHub\GMM-and-GMR\TaskParameterizedGaussianMixtureModels\tpgmm\gmr\gmr.py:353: SyntaxWarning: invalid escape sequence '\m'
#   """tiles mean into: \f$\mu^\mathcal{I}\f$ and \f$\mu^\mathcal{O}\f$
# C:\Users\quepe\Documents\GitHub\GMM-and-GMR\TaskParameterizedGaussianMixtureModels\tpgmm\gmr\gmr.py:372: SyntaxWarning: invalid escape sequence '\S'
#   \Sigma = [[\Sigma^\mathcal{I}, \Sigma^\mathcal{IO}], [\Sigma^\mathcal{OI}, \Sigma^\mathcal{O}]]

# %%
class DiffFilter:
    def __init__(self, threshold: float = np.exp(-2)) -> None:
        # if max diff is bigger than np.exp(-2) ~ 0.1353352832366127 -> return false
        self._threshold: float = threshold

    def __call__(self, data: ndarray) -> bool:
        if np.max(np.abs(np.diff(data, axis=0))) >= self._threshold:
            return False
        return True


class GroundFilter:
    def __init__(self, threshold: float = 0.1) -> None:
        self._threshold: float = threshold

    def __call__(self, data: ndarray) -> bool:
        if min(data[:, 2]) <= self._threshold:
            return True
        return False

# %%
trajectories = []
for data_path in glob("data/7days1/processed_data/*/*.txt"):
    data = map(lambda x: ssv_to_ndarray(x), load_txt(data_path))
    data = np.stack(list(data))[:, 2:5]
    trajectories.append(data)

print(f"Loaded {len(trajectories)} trajectories")
diff_filter = DiffFilter()
ground_filter = GroundFilter(0.3)

trajectories = list(filter(ground_filter, filter(diff_filter, trajectories)))
plot_trajectories(
    title="flight",
    trajectories=trajectories[54][None],
    legend=True,
)
# Out:
# Loaded 344 trajectories
# (<Figure size 1000x800 with 1 Axes>, <Axes3D: title={'center': 'flight'}>)

# %% [markdown]
# Select one trajectory and generate similar ones based on the selected one

# %%
trajectory = trajectories[54]  # start trajectory

trajectory_vector = np.diff(trajectory, axis=0)

synthetic_trajectories = []
num_trajectories = 120
for _ in range(num_trajectories):
    synthetic_trajectory = np.zeros_like(trajectory) 
    noise = np.random.normal(0, 0.01, size=synthetic_trajectory.shape)
    synthetic_trajectory[0] = trajectory[0] + noise[0]
    for traj_idx in range(1, len(trajectory)):
        traj_point = synthetic_trajectory[traj_idx - 1] + trajectory_vector[traj_idx - 1] + noise[traj_idx]
        synthetic_trajectory[traj_idx] = traj_point
    synthetic_trajectories.append(np.stack(synthetic_trajectory))
# noise = np.random.normal(0, 0.5,)

plot_trajectories(
    title="flight",
    trajectories=synthetic_trajectories,
    legend=False,
)
# Out:
# (<Figure size 1000x800 with 1 Axes>, <Axes3D: title={'center': 'flight'}>)

# %%
trajectories = synthetic_trajectories

# %% [markdown]
# Preprocess data with following requirements.
#
# - Trajectories have to have all the same length
# - Transform into start position
# - Transform into end position
# - If not provided add time vector

# %%
from enum import Enum
from typing import Any, List, Literal, Union
from scipy import interpolate

from numpy import ndarray


class SamplingMode(Enum):
    MIN = 0
    MEAN = 1
    MAX = 2


class PreProcessor:
    def __init__(
        self,
        capture_frequency: float,
        num_samples: Union[
            Literal[SamplingMode.MAX],
            Literal[SamplingMode.MEAN],
            Literal[SamplingMode.MIN],
            int,
        ] = SamplingMode.MIN,
        frame_idx: List[int] = [0, -1],
    ) -> None:
        self.capture_frequency = capture_frequency
        self.num_samples = num_samples
        self.frame_idx = frame_idx  # determine from which frames inside the trajectory are determined to be reference frames for the GMR

    def __call__(self, data: Union[List[ndarray], ndarray]) -> ndarray:
        """_summary_

        Args:
            data (Union[List[ndarray], ndarray]): shape: (num_trajectories, num_points, num_features)
                num_trajectories: number of recorded and loaded trajectories
                num cluster points refers to the number of points inside a point framework like hand-landmarks (num_cluster_points = 21) from google mediapipe

        Returns:
            ndarray: shape: (num_trajectories, num_frames, num_points, num_features) num features contains x, y, z and time
        """
        trajectories = self.unify_length(data, self.num_samples)
        
        # translate trajectories into respected start and end frames with a constant rotation matrix
        local_trajectories = self.translate_trajectories(trajectories)

        # add capture time information
        local_trajectories = self.add_time(local_trajectories)

        # local_trajectories = np.concatenate(local_trajectories, axis=1)
        return local_trajectories
    
    def unify_length(self, 
        trajectories: List[ndarray],
        sampling_mode: Union[
            Literal[SamplingMode.MIN],
            Literal[SamplingMode.MAX],
            Literal[SamplingMode.MEAN],
            int,
        ] = SamplingMode.MIN,
    ) -> ndarray:
        """Normalize all the demos list and put all the values together in an unique
        ndarray: UNDERSAMPLING

        Args:
            demos (List[ndarray]): list of demonstration data. Each list element is a demonstration (ndarray).
            A demonstration element is a ndarray with shape (len_demo, num_features). Assumption num_features is greater equal 3 -> first
            indices: x, y, z information
            sampling_mode (SamplingMode, optional): _description_. Defaults to SamplingMode.UNDERSAMPLING.

        Raises:
            NotImplementedError: if sampling_mode is not equal SamplingMode.UNDERSAMPLING

        Returns:
            ndarray: all trajectories interpolated to the same length. Shape: (num_trajectories, num_points, 3). Last dimension is x, y, z
        """
        num_samples = None
        trajectoriy_lengths = map(lambda x: len(x), trajectories)
        if sampling_mode == SamplingMode.MIN:
            num_samples = min(trajectoriy_lengths)
        elif sampling_mode == SamplingMode.MEAN:
            num_samples = int(np.mean(trajectoriy_lengths))
        elif sampling_mode == SamplingMode.MAX:
            num_samples = max(trajectoriy_lengths)
        elif isinstance(sampling_mode, int):
            num_samples = sampling_mode

        unified_trajectories = []
        for trajectory in trajectories:
            # create splines and sample points from the spline to get a uniform length of each trajectory
            tck, u = interpolate.splprep(trajectory[:, :3].T, k=3, s=0)
            u = np.linspace(0, 1, num=num_samples, endpoint=True)
            unified_trajectories.append(interpolate.splev(u, tck))

        unified_trajectories = np.stack(unified_trajectories).swapaxes(-1, -2)

        return unified_trajectories

    def translate_trajectories(self, trajectories: ndarray, ) -> ndarray:
        # get pick and place translation from trajectories as first and last position
        start_end_translation = trajectories[:, [0, -1], :]
        means = start_end_translation.mean(0)
        print("mean start: ", means[0])
        print("mean end: ", means[1])
        result = np.empty((2, *trajectories.shape))
        for frame_idx in range(2):
            points = trajectories.swapaxes(0, 1) - start_end_translation[:, frame_idx] 
            result[frame_idx] = points.swapaxes(0, 1)
        
        return result

    def add_time(
        self, trajectories: Union[List[ndarray], ndarray]) -> Union[List[ndarray], ndarray]:
        """adds to every point on the trajectory its recorded timestamp with the assumption all trajectories started at t = 0

        Args:
            trajectories (Union[List[ndarray], ndarray]): trajectories. Shape: (...., num_points, 3)
            freq (float): recording frequency

        Returns:
            Union[List[ndarray]: trajectories with time information. Shape (..., num_points, 4). Last dimension is (x, y, z, time)
        """

        if isinstance(trajectories, ndarray):
            # create time vector
            traj_shape = trajectories.shape
            # ASSUMPTION: values at index: -2 = num_points

            time = np.arange(
                0,
                traj_shape[-2] * (1 / self.capture_frequency),
                1 / self.capture_frequency,
            )
            print(f"time feature between {time[0]} and {time[-1]}. {len(time)} time instances")

            # bump up dimensionality to match trajectories
            time = time.reshape((1,) * 2 + (-1, 1))
            time = np.broadcast_to(time, (*traj_shape[:-1], 1))

            return np.concatenate([trajectories, time], axis=-1)

        else:
            raise ValueError("wrong input type. Supported is: ndarray")
        

num_samples = 200
capture_freq = 100
pre_processor = PreProcessor(capture_freq, num_samples)

pre_processed_data = pre_processor(trajectories)
# plot_trajectories(trajectories=pre_processed_data[0, [11]])
# Out:
# mean start:  [-1.71640727 -4.07874003  0.60288164]
# mean end:  [0.95539369 0.14603061 0.23144609]
# time feature between 0.0 and 1.99. 200 time instances

# %%
from tpgmm.tpgmm.tpgmm import TPGMM
print(f"shape: , {pre_processed_data[0, [11]].shape}")

print(f"Pre-processed data shape: {pre_processed_data.shape}")
# pre_processed_data = pre_processed_data.swapaxes(0, 1)  # swap axes to have num_trajectories as first dimension
# print(f"Pre-processed data shape after swap: {pre_processed_data.shape}")
tpgmm = TPGMM(6, verbose=True)
num_trajectories = pre_processed_data.shape[1]
concatenated_trajectories = np.reshape(
    pre_processed_data, (2, num_trajectories * num_samples, 4)
)

print(f"Concatenated trajectories shape: {concatenated_trajectories.shape}")


tpgmm.fit(concatenated_trajectories)
# Out:
# shape: , (1, 200, 4)
# Pre-processed data shape: (2, 120, 200, 4)
# Concatenated trajectories shape: (2, 24000, 4)
# Started KMeans clustering
# finished KMeans clustering
# Start expectation maximization
# 	 Initial log likelihood: 5350.5008975823275
#
# Epoch 1/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 180314.8913743092 improvement 174964.39047672687
# Epoch 2/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 182722.92743966798 improvement 2408.036065358785
# Epoch 3/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 184657.35561967926 improvement 1934.4281800112803
# Epoch 4/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 186316.69141926966 improvement 1659.3357995903934
# Epoch 5/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 187869.96906878304 improvement 1553.2776495133876
# Epoch 6/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 189034.04145480177 improvement 1164.0723860187281
# Epoch 7/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 189811.84944913443 improvement 777.8079943326593
# Epoch 8/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 190419.3578424898 improvement 607.5083933553542
# Epoch 9/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 190900.88829462026 improvement 481.5304521304788
# Epoch 10/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 191283.00477987604 improvement 382.1164852557704
# Epoch 11/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 191591.24993286363 improvement 308.245152987598
# Epoch 12/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 191846.58025241003 improvement 255.3303195463959
# Epoch 13/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 192066.20581487304 improvement 219.62556246301392
# Epoch 14/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 192260.97666498297 improvement 194.77085010992596
# Epoch 15/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 192437.22147299274 improvement 176.24480800976744
# Epoch 16/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 192599.5400008926 improvement 162.31852789985714
# Epoch 17/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 192751.92040436948 improvement 152.38040347688366
# Epoch 18/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 192897.29653462608 improvement 145.37613025659812
# Epoch 19/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193037.58153675857 improvement 140.28500213249936
# Epoch 20/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193173.50906683638 improvement 135.92753007780993
# Epoch 21/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193303.29906411807 improvement 129.78999728168128
# Epoch 22/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193423.14141525162 improvement 119.8423511335568
# Epoch 23/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193529.5886482172 improvement 106.44723296558368
# Epoch 24/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193621.6181880783 improvement 92.02953986110515
# Epoch 25/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193700.5055099965 improvement 78.88732191818417
# Epoch 26/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193768.2550969693 improvement 67.74958697281545
# Epoch 27/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193826.66403894627 improvement 58.408941976958886
# Epoch 28/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193877.1614420802 improvement 50.49740313392249
# Epoch 29/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193920.88800137304 improvement 43.726559292845195
# Epoch 30/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193958.7790256042 improvement 37.891024231154006
# Epoch 31/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 193991.61565678456 improvement 32.836631180369295
# Epoch 32/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194020.059222237 improvement 28.44356545244227
# Epoch 33/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194044.68000900286 improvement 24.620786765852245
# Epoch 34/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194065.98032132123 improvement 21.30031231837347
# Epoch 35/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194084.40902192018 improvement 18.428700598946307
# Epoch 36/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194100.3681419363 improvement 15.959120016137604
# Epoch 37/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194114.2151608605 improvement 13.847018924192525
# Epoch 38/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194126.26444769857 improvement 12.049286838067928
# Epoch 39/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194136.78951479637 improvement 10.525067097798456
# Epoch 40/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194146.02628069604 improvement 9.236765899666352
# Epoch 41/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194154.17698178047 improvement 8.15070108443615
# Epoch 42/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194161.4143048516 improvement 7.237323071138235
# Epoch 43/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194167.88539531577 improvement 6.471090464154258
# Epoch 44/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194173.71551522915 improvement 5.830119913385715
# Epoch 45/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194179.01124726614 improvement 5.295732036989648
# Epoch 46/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194183.8632379695 improvement 4.8519907033478376
# Epoch 47/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194188.3485309563 improvement 4.48529298682115
# Epoch 48/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194192.53256054642 improvement 4.184029590105638
# Epoch 49/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194196.4708720203 improvement 3.9383114738739096
# Epoch 50/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194200.21062028524 improvement 3.7397482649539597
# Epoch 51/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194203.79188330856 improvement 3.5812630233122036
# Epoch 52/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194207.24881429347 improvement 3.4569309849175625
# Epoch 53/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194210.6106482803 improvement 3.361833986826241
# Epoch 54/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194213.90257431642 improvement 3.2919260361231863
# Epoch 55/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194217.14648275112 improvement 3.243908434698824
# Epoch 56/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194220.36159768607 improvement 3.2151149349519983
# Epoch 57/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194223.56500621774 improvement 3.203408531669993
# Epoch 58/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194226.77209800814 improvement 3.2070917903911322
# Epoch 59/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194229.99693014624 improvement 3.22483213810483
# Epoch 60/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194233.2525326733 improvement 3.255602527060546
# Epoch 61/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194236.55116914416 improvement 3.29863647086313
# Epoch 62/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194239.90456410672 improvement 3.3533949625561945
# Epoch 63/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194243.3241056315 improvement 3.41954152478138
# Epoch 64/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194246.8210267328 improvement 3.4969211012939923
# Epoch 65/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194250.40656571835 improvement 3.585538985556923
# Epoch 66/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194254.09210340842 improvement 3.6855376900639385
# Epoch 67/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194257.88927566074 improvement 3.797172252321616
# Epoch 68/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194261.8100631331 improvement 3.920787472365191
# Epoch 69/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194265.86686567712 improvement 4.056802544015227
# Epoch 70/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194270.07257419196 improvement 4.205708514840808
# Epoch 71/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194274.44065466465 improvement 4.368080472690053
# Epoch 72/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194278.98525425093 improvement 4.544599586282857
# Epoch 73/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194283.72132596007 improvement 4.736071709136013
# Epoch 74/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194288.66474897251 improvement 4.9434230124461465
# Epoch 75/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194293.83240232576 improvement 5.167653353244532
# Epoch 76/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194299.24214013945 improvement 5.409737813693937
# Epoch 77/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194304.91262614832 improvement 5.6704860088648275
# Epoch 78/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194310.86301946858 improvement 5.950393320264993
# Epoch 79/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194317.11255802645 improvement 6.24953855786589
# Epoch 80/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194323.68014133145 improvement 6.5675833050045185
# Epoch 81/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194330.58403428827 improvement 6.903892956819618
# Epoch 82/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194337.84176238105 improvement 7.257728092779871
# Epoch 83/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194345.47014379464 improvement 7.628381413582247
# Epoch 84/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194353.4852657005 improvement 8.015121905860724
# Epoch 85/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194361.9021622386 improvement 8.41689653811045
# Epoch 86/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194370.73406313674 improvement 8.831900898134336
# Epoch 87/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194379.99132483942 improvement 9.257261702674441
# Epoch 88/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194389.68038953756 improvement 9.689064698148286
# Epoch 89/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194399.8031637389 improvement 10.122774201328866
# Epoch 90/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194410.3569831865 improvement 10.553819447610294
# Epoch 91/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194421.334960925 improvement 10.977977738511981
# Epoch 92/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194432.72630870054 improvement 11.39134777552681
# Epoch 93/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194444.5164167757 improvement 11.790108075161697
# Epoch 94/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194456.68693245942 improvement 12.170515683712438
# Epoch 95/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194469.21628909907 improvement 12.529356639657635
# Epoch 96/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194482.0807488344 improvement 12.86445973534137
# Epoch 97/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194495.255435554 improvement 13.17468671957613
# Epoch 98/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194508.71492892777 improvement 13.459493373782607
# Epoch 99/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194522.43377335405 improvement 13.718844426271971
# Epoch 100/100
# shape of probabilities:(2, 6, 24000)
# Log likelihood: 194536.38749302505 improvement 13.953719671000727

# %%
from tpgmm.gmr.gmr import GaussianMixtureRegression
from tpgmm.utils.plot.plot import plot_ellipsoids

frame_idx = 0
plot_ellipsoids(
    title="GMM from start perspective", means=tpgmm.means_[frame_idx, :, :3], covs=tpgmm.covariances_[frame_idx, :, :3, :3], legend=True
)
frame_idx = 1
plot_ellipsoids(
    title="GMM from end perspective", means=tpgmm.means_[frame_idx, :, :3], covs=tpgmm.covariances_[frame_idx, :, :3, :3], legend=True
)
# Out:
# (<Figure size 1000x800 with 1 Axes>,
#  <Axes3D: title={'center': 'GMM from end perspective'}>)

# %%
gmr = GaussianMixtureRegression.from_tpgmm(tpgmm, [3])

print(f"TPGMM means shape: {tpgmm.means_.shape}")  # Should be (2, 17, 6)
print(f"TPGMM covariances shape: {tpgmm.covariances_.shape}")  # Should be (2, 17, 6, 6)
print(f"GMR input dimensions: {gmr.input_idx}")
print(f"GMR output dimensions: {gmr.output_idx}")

translation = np.array(
    [[0.67434406, -0.10956558, 0.31207092], [1.52133899, 0.03424608, 0.40956669]]
)
translation = np.array([[ 0.64892812, -0.00127319,  0.27268653], [3.25658728, 4.49575041, 0.95660171]])
rotation_matrix = np.eye(3)[None].repeat(2, axis=0)
gmr.fit(translation=translation, rotation_matrix=rotation_matrix)
# Out:
# TPGMM means shape: (2, 6, 4)
# TPGMM covariances shape: (2, 6, 4, 4)
# GMR input dimensions: [3]
# GMR output dimensions: [0, 1, 2]

# %%
from tpgmm.utils.plot.plot import scatter


input_data = np.linspace(0, 2, 200)[:, None]
print(f"Input data shape: {input_data.shape}")  # Should be (200, 1)
mu, cov = gmr.predict(input_data)

fig, ax = scatter(title="Reconstructed Trajectory", data=translation[: ,None])
fig, ax = plot_trajectories(trajectories=mu[None], fig=fig, ax=ax, legend=True)
plot_ellipsoids(
    means=mu[::20], covs=cov[::20], fig=fig, ax=ax, alpha=0.3
)
print(f"Distance to desired positions:\n start: {np.linalg.norm(translation[0] - mu[0])} \n end: {np.linalg.norm(translation[1] - mu[-1])}")
# Out:
# Input data shape: (200, 1)
# Distance to desired positions:
#  start: 0.04822119929238975
#  end: 0.173749451089149
